# %% [markdown]
# # Live Face-Mask Detection - Using YOLO pretrained model
# # conda activate yolo

# %%
import cv2
from ultralytics import YOLO
import pygame
import time

# Load custom face mask detection YOLO model
# model = YOLO("/media/akashs/FA22E72622E6E69B/DATA1_disk/MyGithub/Mask_Detection/archive/runs/detect/train2/weights/best.pt")  # Change to your model path
model = YOLO("./best.pt")  # Change to your model path
names = model.names  # Should include 'mask' and 'no_mask'
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
names
# Out:
# {0: 'with_mask', 1: 'without_mask', 2: 'mask_weared_incorrect'}

# %% [markdown]
# ### Detection

# %%
# Access default live-cam (0)
cap = cv2.VideoCapture(2)
# cap = cv2.VideoCapture("mask_video2.mp4")

fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_video_filename = f"recordings/recorded_{time.strftime('%Y%m%d_%H%M%S')}.avi"
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video_filename, fourcc, 20.0, (frame_width, frame_height))


img_counter = 0
print("Live cam started. Press 's' to save image, 'q' to quit.")

# Optional sound setup
pygame.mixer.init()
alert_sound = pygame.mixer.Sound("chime_alert.mp3")

alert_triggered = False

while True:
    ret, frame = cap.read()
    if not ret:
        print("Live cam frame not received")
        break

    # -----------------------------
    # Draw Line, Rectangle, Circle, Text
    # -----------------------------
    height, width = frame.shape[:2]

    results = model(frame)

    # 🔹 Extract results
    boxes = results[0].boxes
    names = model.names  # COCO class names

    # Uses OpenCV's haarcascade
    # https://github.com/opencv/opencv/tree/master/data/haarcascades
    
    detected_classes = [int(box.cls[0].item()) for box in boxes]
    labels = [model.names[cls_id] for cls_id in detected_classes]

    # Draw detection boxes and play alert for "without_mask"
    for box, label in zip(boxes, labels):
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = box.conf[0].item()
        label_text = f"{label}: {conf:.2f}"

        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        cv2.putText(frame, label_text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (255, 0, 0), 2)
        print(f"🟢 Detected: {label_text} at ({x1}, {y1}, {x2}, {y2})")

        # Play sound for each "without_mask" detected
        if "without_mask" in label.lower():
            alert_sound.play()

        
    # -----------------------------
    # Save frame to video file
    # -----------------------------
    out.write(frame)

    # -----------------------------
    # Show live-cam feed
    # -----------------------------
    cv2.imshow('Live-cam Feed with Drawing', frame)

    # -----------------------------
    # Keypress handling
    # -----------------------------
    key = cv2.waitKey(1)
    if key & 0xFF == ord('q'):
        print("Exiting live-cam...")
        break
    elif key & 0xFF == ord('s'):
        # Save snapshot image
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        img_filename = f"snapshot_{timestamp}.jpg"
        cv2.imwrite(img_filename, frame)
        print(f"Snapshot saved: {img_filename}")
        img_counter += 1

# -----------------------------
# Release resources
# -----------------------------
cap.release()
out.release()
cv2.destroyAllWindows()
print(f"Recorded video saved as: {output_video_filename}")
# Out:
# Live cam started. Press 's' to save image, 'q' to quit.
# /home/akashs/miniconda3/envs/yolo/lib/python3.13/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# 0: 384x640 6 with_masks, 4 without_masks, 262.6ms
# Speed: 12.2ms preprocess, 262.6ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.72 at (1268, 364, 1311, 411)
# 🟢 Detected: with_mask: 0.69 at (1829, 365, 1872, 406)
# 🟢 Detected: with_mask: 0.64 at (1162, 364, 1194, 404)
# 🟢 Detected: without_mask: 0.59 at (409, 373, 439, 408)
# 🟢 Detected: with_mask: 0.43 at (799, 402, 843, 445)
# 🟢 Detected: with_mask: 0.43 at (1354, 422, 1404, 477)
# 🟢 Detected: without_mask: 0.37 at (539, 388, 575, 427)
# 🟢 Detected: with_mask: 0.31 at (1148, 366, 1184, 412)
# 🟢 Detected: without_mask: 0.26 at (983, 365, 1017, 409)
# 🟢 Detected: with_mask: 0.26 at (1341, 409, 1369, 460)
#
# 0: 384x640 7 with_masks, 5 without_masks, 413.6ms
# Speed: 12.0ms preprocess, 413.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.66 at (1829, 369, 1868, 408)
# 🟢 Detected: with_mask: 0.57 at (1161, 364, 1193, 405)
# 🟢 Detected: without_mask: 0.57 at (407, 369, 437, 403)
# 🟢 Detected: without_mask: 0.52 at (1267, 366, 1309, 413)
# 🟢 Detected: with_mask: 0.52 at (1156, 365, 1189, 409)
# 🟢 Detected: with_mask: 0.47 at (1355, 416, 1412, 478)
# 🟢 Detected: without_mask: 0.40 at (982, 369, 1014, 413)
# 🟢 Detected: without_mask: 0.36 at (534, 387, 571, 430)
# 🟢 Detected: with_mask: 0.34 at (800, 405, 841, 443)
# 🟢 Detected: with_mask: 0.30 at (1144, 366, 1181, 412)
# 🟢 Detected: with_mask: 0.28 at (1129, 378, 1157, 419)
# 🟢 Detected: without_mask: 0.27 at (1489, 363, 1531, 415)
#
# 0: 384x640 4 with_masks, 4 without_masks, 173.7ms
# Speed: 12.8ms preprocess, 173.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.75 at (1831, 371, 1871, 411)
# 🟢 Detected: without_mask: 0.67 at (405, 371, 434, 407)
# 🟢 Detected: with_mask: 0.65 at (1364, 421, 1416, 479)
# 🟢 Detected: with_mask: 0.63 at (1161, 364, 1194, 405)
# 🟢 Detected: without_mask: 0.53 at (533, 388, 569, 430)
# 🟢 Detected: with_mask: 0.42 at (801, 405, 841, 444)
# 🟢 Detected: without_mask: 0.35 at (980, 369, 1010, 411)
# 🟢 Detected: without_mask: 0.26 at (1267, 363, 1309, 410)
#
# 0: 384x640 5 with_masks, 3 without_masks, 169.8ms
# Speed: 9.4ms preprocess, 169.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.76 at (1363, 418, 1417, 478)
# 🟢 Detected: with_mask: 0.76 at (1831, 371, 1874, 414)
# 🟢 Detected: with_mask: 0.68 at (1161, 364, 1193, 403)
# 🟢 Detected: without_mask: 0.65 at (1267, 365, 1309, 410)
# 🟢 Detected: without_mask: 0.58 at (406, 372, 434, 407)
# 🟢 Detected: with_mask: 0.42 at (1484, 365, 1525, 415)
# 🟢 Detected: with_mask: 0.38 at (805, 407, 837, 440)
# 🟢 Detected: without_mask: 0.30 at (533, 385, 570, 428)
#
# 0: 384x640 6 with_masks, 5 without_masks, 187.0ms
# Speed: 13.7ms preprocess, 187.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.80 at (1269, 364, 1310, 406)
# 🟢 Detected: with_mask: 0.76 at (1833, 372, 1875, 418)
# 🟢 Detected: with_mask: 0.73 at (1371, 418, 1422, 476)
# 🟢 Detected: with_mask: 0.65 at (1162, 365, 1193, 403)
# 🟢 Detected: without_mask: 0.63 at (529, 388, 570, 437)
# 🟢 Detected: without_mask: 0.61 at (1104, 367, 1139, 413)
# 🟢 Detected: without_mask: 0.42 at (405, 374, 433, 409)
# 🟢 Detected: with_mask: 0.40 at (690, 390, 722, 432)
# 🟢 Detected: with_mask: 0.35 at (807, 408, 835, 439)
# 🟢 Detected: with_mask: 0.32 at (1482, 365, 1527, 416)
# 🟢 Detected: without_mask: 0.31 at (529, 394, 566, 431)
#
# 0: 384x640 5 with_masks, 4 without_masks, 185.0ms
# Speed: 14.6ms preprocess, 185.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.77 at (1835, 373, 1875, 420)
# 🟢 Detected: without_mask: 0.73 at (1102, 367, 1137, 412)
# 🟢 Detected: without_mask: 0.69 at (526, 387, 568, 437)
# 🟢 Detected: with_mask: 0.62 at (1163, 367, 1193, 403)
# 🟢 Detected: without_mask: 0.58 at (399, 373, 429, 412)
# 🟢 Detected: without_mask: 0.49 at (1266, 366, 1309, 410)
# 🟢 Detected: with_mask: 0.43 at (1480, 366, 1523, 416)
# 🟢 Detected: with_mask: 0.41 at (688, 387, 720, 425)
# 🟢 Detected: with_mask: 0.37 at (1372, 407, 1431, 473)
#
# 0: 384x640 4 with_masks, 3 without_masks, 179.9ms
# Speed: 11.7ms preprocess, 179.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.81 at (1837, 376, 1875, 419)
# 🟢 Detected: with_mask: 0.65 at (1160, 374, 1192, 410)
# 🟢 Detected: without_mask: 0.62 at (1269, 376, 1313, 421)
# 🟢 Detected: with_mask: 0.61 at (1374, 407, 1434, 472)
# 🟢 Detected: without_mask: 0.45 at (524, 385, 565, 431)
# 🟢 Detected: without_mask: 0.45 at (1102, 368, 1135, 409)
# 🟢 Detected: with_mask: 0.45 at (1476, 370, 1516, 418)
#
# 0: 384x640 6 with_masks, 2 without_masks, 229.9ms
# Speed: 12.1ms preprocess, 229.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.78 at (1837, 376, 1875, 417)
# 🟢 Detected: without_mask: 0.73 at (1268, 367, 1313, 418)
# 🟢 Detected: with_mask: 0.57 at (1160, 376, 1192, 412)
# 🟢 Detected: with_mask: 0.54 at (1100, 371, 1134, 413)
# 🟢 Detected: with_mask: 0.52 at (1474, 375, 1513, 425)
# 🟢 Detected: without_mask: 0.41 at (520, 389, 562, 438)
# 🟢 Detected: with_mask: 0.39 at (863, 359, 909, 407)
# 🟢 Detected: with_mask: 0.38 at (1379, 406, 1436, 467)
#
# 0: 384x640 6 with_masks, 3 without_masks, 153.1ms
# Speed: 4.5ms preprocess, 153.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.77 at (1837, 375, 1876, 418)
# 🟢 Detected: with_mask: 0.68 at (1379, 403, 1437, 464)
# 🟢 Detected: without_mask: 0.66 at (1268, 377, 1313, 425)
# 🟢 Detected: with_mask: 0.53 at (1474, 375, 1514, 426)
# 🟢 Detected: with_mask: 0.50 at (1161, 381, 1192, 418)
# 🟢 Detected: with_mask: 0.44 at (1100, 371, 1132, 410)
# 🟢 Detected: without_mask: 0.34 at (861, 362, 906, 405)
# 🟢 Detected: with_mask: 0.33 at (778, 403, 811, 448)
# 🟢 Detected: without_mask: 0.25 at (517, 387, 561, 431)
#
# 0: 384x640 4 with_masks, 5 without_masks, 166.5ms
# Speed: 5.9ms preprocess, 166.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.77 at (1837, 375, 1877, 420)
# 🟢 Detected: with_mask: 0.65 at (1385, 407, 1438, 462)
# 🟢 Detected: with_mask: 0.60 at (1161, 382, 1193, 420)
# 🟢 Detected: without_mask: 0.60 at (1271, 377, 1311, 422)
# 🟢 Detected: without_mask: 0.43 at (1269, 371, 1309, 414)
# 🟢 Detected: without_mask: 0.43 at (516, 386, 561, 431)
# 🟢 Detected: without_mask: 0.39 at (689, 371, 719, 409)
# 🟢 Detected: without_mask: 0.38 at (1100, 371, 1132, 414)
# 🟢 Detected: with_mask: 0.29 at (1474, 376, 1511, 432)
#
# 0: 384x640 2 with_masks, 5 without_masks, 153.6ms
# Speed: 9.2ms preprocess, 153.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.76 at (513, 386, 561, 437)
# 🟢 Detected: with_mask: 0.76 at (1837, 375, 1877, 419)
# 🟢 Detected: with_mask: 0.59 at (1162, 383, 1193, 421)
# 🟢 Detected: without_mask: 0.51 at (1270, 376, 1313, 423)
# 🟢 Detected: without_mask: 0.31 at (387, 384, 419, 425)
# 🟢 Detected: without_mask: 0.27 at (687, 372, 716, 406)
# 🟢 Detected: without_mask: 0.26 at (1100, 375, 1132, 416)
#
# 0: 384x640 4 with_masks, 4 without_masks, 156.6ms
# Speed: 12.8ms preprocess, 156.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.76 at (1836, 375, 1876, 419)
# 🟢 Detected: without_mask: 0.76 at (514, 384, 559, 434)
# 🟢 Detected: with_mask: 0.59 at (1163, 385, 1194, 421)
# 🟢 Detected: with_mask: 0.48 at (1099, 380, 1131, 421)
# 🟢 Detected: without_mask: 0.46 at (383, 385, 413, 417)
# 🟢 Detected: with_mask: 0.43 at (1392, 409, 1445, 467)
# 🟢 Detected: without_mask: 0.36 at (1273, 382, 1316, 425)
# 🟢 Detected: without_mask: 0.28 at (858, 357, 903, 404)
#
# 0: 384x640 4 with_masks, 3 without_masks, 214.9ms
# Speed: 4.9ms preprocess, 214.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.77 at (1836, 374, 1876, 418)
# 🟢 Detected: with_mask: 0.68 at (1394, 408, 1453, 470)
# 🟢 Detected: without_mask: 0.60 at (517, 387, 557, 430)
# 🟢 Detected: without_mask: 0.57 at (383, 389, 412, 422)
# 🟢 Detected: with_mask: 0.54 at (1163, 384, 1195, 421)
# 🟢 Detected: with_mask: 0.40 at (1096, 379, 1130, 421)
# 🟢 Detected: without_mask: 0.32 at (1272, 383, 1314, 426)
#
# 0: 384x640 4 with_masks, 4 without_masks, 154.0ms
# Speed: 15.5ms preprocess, 154.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.77 at (1835, 374, 1876, 418)
# 🟢 Detected: without_mask: 0.63 at (512, 393, 555, 438)
# 🟢 Detected: with_mask: 0.55 at (1162, 385, 1194, 422)
# 🟢 Detected: with_mask: 0.52 at (1398, 413, 1459, 475)
# 🟢 Detected: without_mask: 0.35 at (1273, 381, 1313, 425)
# 🟢 Detected: without_mask: 0.34 at (381, 386, 412, 422)
# 🟢 Detected: without_mask: 0.28 at (972, 369, 1010, 415)
# 🟢 Detected: with_mask: 0.28 at (1096, 380, 1129, 423)
#
# 0: 384x640 5 with_masks, 3 without_masks, 165.1ms
# Speed: 14.1ms preprocess, 165.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.80 at (1836, 374, 1877, 418)
# 🟢 Detected: without_mask: 0.61 at (514, 395, 554, 437)
# 🟢 Detected: with_mask: 0.53 at (1163, 384, 1194, 422)
# 🟢 Detected: without_mask: 0.47 at (1278, 385, 1315, 426)
# 🟢 Detected: without_mask: 0.47 at (975, 374, 1019, 419)
# 🟢 Detected: with_mask: 0.44 at (1094, 380, 1128, 423)
# 🟢 Detected: with_mask: 0.43 at (1409, 423, 1461, 475)
# 🟢 Detected: with_mask: 0.29 at (1424, 464, 1486, 507)
#
# 0: 384x640 7 with_masks, 3 without_masks, 162.1ms
# Speed: 18.1ms preprocess, 162.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.81 at (1836, 375, 1876, 417)
# 🟢 Detected: with_mask: 0.77 at (1412, 426, 1466, 479)
# 🟢 Detected: without_mask: 0.61 at (1270, 382, 1313, 426)
# 🟢 Detected: without_mask: 0.49 at (978, 375, 1021, 420)
# 🟢 Detected: with_mask: 0.48 at (1093, 383, 1127, 423)
# 🟢 Detected: with_mask: 0.45 at (1164, 385, 1195, 422)
# 🟢 Detected: without_mask: 0.35 at (514, 396, 552, 440)
# 🟢 Detected: with_mask: 0.27 at (1151, 384, 1181, 420)
# 🟢 Detected: with_mask: 0.27 at (1354, 431, 1406, 491)
# 🟢 Detected: with_mask: 0.27 at (1677, 372, 1704, 399)
#
# 0: 384x640 4 with_masks, 4 without_masks, 152.4ms
# Speed: 11.7ms preprocess, 152.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.91 at (1415, 432, 1468, 481)
# 🟢 Detected: with_mask: 0.83 at (1836, 376, 1876, 420)
# 🟢 Detected: without_mask: 0.73 at (1270, 381, 1314, 426)
# 🟢 Detected: with_mask: 0.63 at (1162, 383, 1195, 422)
# 🟢 Detected: without_mask: 0.61 at (978, 377, 1022, 421)
# 🟢 Detected: without_mask: 0.37 at (510, 399, 552, 444)
# 🟢 Detected: with_mask: 0.35 at (1091, 382, 1125, 424)
# 🟢 Detected: without_mask: 0.32 at (509, 392, 545, 434)
#
# 0: 384x640 4 with_masks, 3 without_masks, 233.6ms
# Speed: 6.1ms preprocess, 233.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.87 at (1414, 432, 1469, 483)
# 🟢 Detected: with_mask: 0.78 at (1837, 378, 1878, 420)
# 🟢 Detected: without_mask: 0.70 at (1269, 381, 1313, 427)
# 🟢 Detected: without_mask: 0.59 at (978, 377, 1021, 421)
# 🟢 Detected: with_mask: 0.52 at (1162, 383, 1194, 421)
# 🟢 Detected: with_mask: 0.41 at (1152, 382, 1188, 420)
# 🟢 Detected: without_mask: 0.39 at (508, 392, 541, 433)
#
# 0: 384x640 5 with_masks, 3 without_masks, 261.3ms
# Speed: 17.0ms preprocess, 261.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.81 at (1416, 436, 1473, 485)
# 🟢 Detected: with_mask: 0.77 at (1839, 379, 1880, 422)
# 🟢 Detected: without_mask: 0.66 at (1269, 382, 1312, 427)
# 🟢 Detected: with_mask: 0.59 at (1141, 381, 1182, 420)
# 🟢 Detected: with_mask: 0.48 at (1162, 382, 1194, 420)
# 🟢 Detected: without_mask: 0.39 at (503, 388, 538, 428)
# 🟢 Detected: without_mask: 0.34 at (981, 378, 1021, 421)
# 🟢 Detected: with_mask: 0.28 at (1033, 359, 1060, 394)
#
# 0: 384x640 5 with_masks, 4 without_masks, 183.0ms
# Speed: 3.3ms preprocess, 183.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.80 at (1840, 380, 1881, 423)
# 🟢 Detected: with_mask: 0.73 at (1418, 437, 1476, 486)
# 🟢 Detected: with_mask: 0.66 at (1138, 380, 1179, 418)
# 🟢 Detected: without_mask: 0.59 at (1269, 380, 1310, 425)
# 🟢 Detected: with_mask: 0.51 at (1162, 381, 1193, 417)
# 🟢 Detected: without_mask: 0.47 at (500, 390, 533, 430)
# 🟢 Detected: with_mask: 0.39 at (1133, 380, 1162, 419)
# 🟢 Detected: without_mask: 0.37 at (500, 394, 536, 439)
# 🟢 Detected: without_mask: 0.33 at (984, 379, 1024, 420)
#
# 0: 384x640 6 with_masks, 3 without_masks, 167.0ms
# Speed: 15.3ms preprocess, 167.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.81 at (1840, 381, 1880, 424)
# 🟢 Detected: with_mask: 0.80 at (1417, 432, 1477, 486)
# 🟢 Detected: with_mask: 0.66 at (1147, 379, 1189, 418)
# 🟢 Detected: with_mask: 0.62 at (550, 408, 580, 443)
# 🟢 Detected: with_mask: 0.59 at (1161, 380, 1193, 418)
# 🟢 Detected: without_mask: 0.54 at (492, 395, 533, 441)
# 🟢 Detected: without_mask: 0.49 at (1267, 378, 1304, 421)
# 🟢 Detected: with_mask: 0.45 at (1133, 380, 1161, 419)
# 🟢 Detected: without_mask: 0.31 at (983, 376, 1023, 419)
#
# 0: 384x640 6 with_masks, 4 without_masks, 183.6ms
# Speed: 10.0ms preprocess, 183.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.86 at (1416, 428, 1477, 485)
# 🟢 Detected: with_mask: 0.84 at (1838, 380, 1879, 423)
# 🟢 Detected: without_mask: 0.75 at (1263, 379, 1305, 425)
# 🟢 Detected: with_mask: 0.67 at (1128, 378, 1159, 415)
# 🟢 Detected: without_mask: 0.61 at (357, 375, 390, 415)
# 🟢 Detected: with_mask: 0.48 at (553, 406, 579, 439)
# 🟢 Detected: with_mask: 0.42 at (1138, 376, 1182, 415)
# 🟢 Detected: without_mask: 0.41 at (486, 396, 526, 441)
# 🟢 Detected: with_mask: 0.40 at (1792, 389, 1826, 422)
# 🟢 Detected: without_mask: 0.25 at (980, 372, 1020, 418)
#
# 0: 384x640 6 with_masks, 4 without_masks, 158.9ms
# Speed: 13.4ms preprocess, 158.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.88 at (1416, 424, 1477, 484)
# 🟢 Detected: with_mask: 0.81 at (1837, 378, 1879, 424)
# 🟢 Detected: without_mask: 0.69 at (1259, 376, 1295, 416)
# 🟢 Detected: without_mask: 0.59 at (478, 391, 513, 432)
# 🟢 Detected: with_mask: 0.58 at (1125, 378, 1158, 416)
# 🟢 Detected: with_mask: 0.46 at (1789, 390, 1823, 425)
# 🟢 Detected: with_mask: 0.43 at (1154, 378, 1189, 415)
# 🟢 Detected: without_mask: 0.41 at (976, 369, 1018, 419)
# 🟢 Detected: with_mask: 0.38 at (552, 406, 577, 440)
# 🟢 Detected: without_mask: 0.30 at (354, 376, 384, 410)
#
# 0: 384x640 4 with_masks, 4 without_masks, 180.3ms
# Speed: 14.4ms preprocess, 180.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.90 at (474, 390, 514, 436)
# 🟢 Detected: with_mask: 0.86 at (1417, 421, 1480, 482)
# 🟢 Detected: with_mask: 0.81 at (1835, 379, 1878, 426)
# 🟢 Detected: without_mask: 0.62 at (353, 377, 384, 413)
# 🟢 Detected: with_mask: 0.59 at (1122, 378, 1158, 417)
# 🟢 Detected: without_mask: 0.47 at (1081, 368, 1110, 402)
# 🟢 Detected: without_mask: 0.39 at (969, 362, 1018, 420)
# 🟢 Detected: with_mask: 0.36 at (1788, 391, 1820, 427)
#
# 0: 384x640 4 with_masks, 6 without_masks, 152.9ms
# Speed: 16.6ms preprocess, 152.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.90 at (473, 389, 512, 433)
# 🟢 Detected: with_mask: 0.85 at (1836, 379, 1879, 427)
# 🟢 Detected: with_mask: 0.84 at (1418, 417, 1481, 481)
# 🟢 Detected: without_mask: 0.71 at (351, 376, 385, 413)
# 🟢 Detected: without_mask: 0.68 at (1079, 370, 1113, 414)
# 🟢 Detected: without_mask: 0.49 at (968, 362, 1016, 422)
# 🟢 Detected: without_mask: 0.39 at (464, 390, 501, 431)
# 🟢 Detected: with_mask: 0.38 at (1786, 393, 1818, 430)
# 🟢 Detected: without_mask: 0.37 at (845, 379, 892, 430)
# 🟢 Detected: with_mask: 0.29 at (1123, 375, 1158, 417)
#
# 0: 384x640 4 with_masks, 4 without_masks, 167.4ms
# Speed: 10.1ms preprocess, 167.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.91 at (470, 388, 509, 430)
# 🟢 Detected: with_mask: 0.88 at (1423, 414, 1489, 477)
# 🟢 Detected: with_mask: 0.83 at (1839, 379, 1880, 423)
# 🟢 Detected: without_mask: 0.63 at (350, 376, 383, 414)
# 🟢 Detected: without_mask: 0.55 at (1077, 370, 1112, 415)
# 🟢 Detected: with_mask: 0.54 at (1785, 393, 1820, 430)
# 🟢 Detected: with_mask: 0.42 at (1120, 379, 1152, 417)
# 🟢 Detected: without_mask: 0.30 at (847, 380, 892, 431)
#
# 0: 384x640 5 with_masks, 2 without_masks, 172.0ms
# Speed: 4.2ms preprocess, 172.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.90 at (468, 387, 508, 431)
# 🟢 Detected: with_mask: 0.90 at (1428, 411, 1495, 474)
# 🟢 Detected: with_mask: 0.75 at (1844, 379, 1884, 422)
# 🟢 Detected: without_mask: 0.62 at (355, 381, 384, 417)
# 🟢 Detected: with_mask: 0.59 at (1078, 371, 1113, 417)
# 🟢 Detected: with_mask: 0.45 at (1787, 393, 1822, 430)
# 🟢 Detected: with_mask: 0.39 at (1119, 381, 1152, 420)
#
# 0: 384x640 6 with_masks, 2 without_masks, 166.1ms
# Speed: 6.5ms preprocess, 166.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.88 at (1433, 408, 1500, 470)
# 🟢 Detected: without_mask: 0.88 at (468, 387, 508, 430)
# 🟢 Detected: with_mask: 0.66 at (1846, 376, 1890, 418)
# 🟢 Detected: with_mask: 0.58 at (1078, 374, 1114, 420)
# 🟢 Detected: with_mask: 0.48 at (1788, 394, 1824, 432)
# 🟢 Detected: with_mask: 0.48 at (844, 382, 894, 434)
# 🟢 Detected: without_mask: 0.43 at (358, 388, 386, 423)
# 🟢 Detected: with_mask: 0.43 at (1119, 381, 1154, 422)
#
# 0: 384x640 7 with_masks, 4 without_masks, 136.8ms
# Speed: 17.2ms preprocess, 136.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.91 at (468, 386, 510, 432)
# 🟢 Detected: with_mask: 0.84 at (1435, 406, 1506, 469)
# 🟢 Detected: with_mask: 0.77 at (1076, 377, 1113, 423)
# 🟢 Detected: with_mask: 0.68 at (1853, 375, 1894, 417)
# 🟢 Detected: without_mask: 0.61 at (354, 384, 385, 423)
# 🟢 Detected: with_mask: 0.57 at (846, 379, 895, 434)
# 🟢 Detected: with_mask: 0.52 at (1117, 386, 1150, 426)
# 🟢 Detected: with_mask: 0.40 at (1788, 393, 1825, 433)
# 🟢 Detected: with_mask: 0.35 at (787, 377, 835, 437)
# 🟢 Detected: without_mask: 0.32 at (1251, 381, 1290, 427)
# 🟢 Detected: without_mask: 0.28 at (671, 388, 700, 421)
#
# 0: 384x640 7 with_masks, 4 without_masks, 162.2ms
# Speed: 4.0ms preprocess, 162.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.91 at (469, 387, 510, 432)
# 🟢 Detected: with_mask: 0.86 at (1074, 381, 1112, 427)
# 🟢 Detected: with_mask: 0.85 at (1443, 406, 1510, 470)
# 🟢 Detected: with_mask: 0.67 at (1858, 374, 1898, 416)
# 🟢 Detected: without_mask: 0.63 at (353, 384, 383, 425)
# 🟢 Detected: without_mask: 0.61 at (1247, 379, 1288, 423)
# 🟢 Detected: without_mask: 0.43 at (669, 386, 701, 417)
# 🟢 Detected: with_mask: 0.35 at (842, 377, 892, 427)
# 🟢 Detected: with_mask: 0.30 at (788, 376, 834, 437)
# 🟢 Detected: with_mask: 0.29 at (1119, 388, 1148, 428)
# 🟢 Detected: with_mask: 0.27 at (1793, 392, 1827, 428)
#
# 0: 384x640 4 with_masks, 5 without_masks, 149.9ms
# Speed: 12.3ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.88 at (469, 386, 511, 433)
# 🟢 Detected: with_mask: 0.82 at (1074, 382, 1112, 428)
# 🟢 Detected: with_mask: 0.81 at (1449, 407, 1513, 471)
# 🟢 Detected: with_mask: 0.75 at (1859, 374, 1901, 420)
# 🟢 Detected: without_mask: 0.61 at (354, 385, 384, 426)
# 🟢 Detected: without_mask: 0.60 at (1247, 380, 1286, 423)
# 🟢 Detected: with_mask: 0.32 at (1120, 388, 1147, 427)
# 🟢 Detected: without_mask: 0.32 at (291, 442, 333, 489)
# 🟢 Detected: without_mask: 0.27 at (667, 387, 703, 421)
#
# 0: 384x640 4 with_masks, 3 without_masks, 163.1ms
# Speed: 13.0ms preprocess, 163.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.87 at (470, 388, 508, 433)
# 🟢 Detected: with_mask: 0.84 at (1453, 407, 1519, 470)
# 🟢 Detected: with_mask: 0.82 at (1076, 383, 1114, 430)
# 🟢 Detected: with_mask: 0.81 at (1862, 376, 1903, 421)
# 🟢 Detected: without_mask: 0.66 at (1245, 380, 1285, 424)
# 🟢 Detected: without_mask: 0.63 at (355, 388, 384, 426)
# 🟢 Detected: with_mask: 0.42 at (831, 363, 890, 423)
#
# 0: 384x640 3 with_masks, 5 without_masks, 163.8ms
# Speed: 12.7ms preprocess, 163.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.86 at (1077, 385, 1115, 430)
# 🟢 Detected: with_mask: 0.85 at (1455, 413, 1522, 474)
# 🟢 Detected: without_mask: 0.85 at (471, 391, 507, 433)
# 🟢 Detected: with_mask: 0.77 at (1865, 378, 1906, 421)
# 🟢 Detected: without_mask: 0.74 at (1244, 381, 1284, 424)
# 🟢 Detected: without_mask: 0.52 at (353, 387, 383, 427)
# 🟢 Detected: without_mask: 0.39 at (463, 392, 497, 431)
# 🟢 Detected: without_mask: 0.26 at (1249, 392, 1286, 426)
#
# 0: 384x640 4 with_masks, 3 without_masks, 151.0ms
# Speed: 18.2ms preprocess, 151.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.89 at (468, 390, 509, 436)
# 🟢 Detected: with_mask: 0.84 at (1080, 385, 1116, 432)
# 🟢 Detected: with_mask: 0.81 at (1460, 414, 1525, 476)
# 🟢 Detected: with_mask: 0.72 at (1869, 380, 1909, 423)
# 🟢 Detected: without_mask: 0.63 at (1245, 381, 1282, 424)
# 🟢 Detected: without_mask: 0.59 at (353, 386, 384, 427)
# 🟢 Detected: with_mask: 0.45 at (825, 356, 881, 417)
#
# 0: 384x640 5 with_masks, 3 without_masks, 152.1ms
# Speed: 15.7ms preprocess, 152.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.87 at (470, 393, 509, 437)
# 🟢 Detected: with_mask: 0.78 at (1084, 384, 1121, 431)
# 🟢 Detected: with_mask: 0.69 at (1872, 382, 1914, 426)
# 🟢 Detected: with_mask: 0.69 at (1460, 417, 1525, 479)
# 🟢 Detected: without_mask: 0.69 at (1242, 379, 1279, 423)
# 🟢 Detected: without_mask: 0.61 at (353, 386, 383, 426)
# 🟢 Detected: with_mask: 0.36 at (824, 355, 873, 408)
# 🟢 Detected: with_mask: 0.33 at (664, 383, 702, 433)
#
# 0: 384x640 5 with_masks, 3 without_masks, 157.2ms
# Speed: 15.1ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.83 at (470, 395, 511, 440)
# 🟢 Detected: with_mask: 0.77 at (1085, 384, 1123, 430)
# 🟢 Detected: with_mask: 0.75 at (1461, 418, 1527, 484)
# 🟢 Detected: with_mask: 0.68 at (1875, 381, 1917, 427)
# 🟢 Detected: without_mask: 0.60 at (353, 386, 383, 427)
# 🟢 Detected: without_mask: 0.54 at (1243, 381, 1280, 425)
# 🟢 Detected: with_mask: 0.53 at (817, 359, 869, 415)
# 🟢 Detected: with_mask: 0.41 at (662, 382, 699, 430)
#
# 0: 384x640 5 with_masks, 4 without_masks, 173.4ms
# Speed: 6.6ms preprocess, 173.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.81 at (1088, 387, 1124, 430)
# 🟢 Detected: without_mask: 0.79 at (468, 398, 509, 441)
# 🟢 Detected: with_mask: 0.78 at (1462, 425, 1528, 487)
# 🟢 Detected: with_mask: 0.67 at (1880, 380, 1919, 430)
# 🟢 Detected: without_mask: 0.59 at (356, 386, 385, 425)
# 🟢 Detected: with_mask: 0.51 at (813, 353, 863, 409)
# 🟢 Detected: with_mask: 0.44 at (661, 383, 698, 429)
# 🟢 Detected: without_mask: 0.40 at (1239, 380, 1276, 422)
# 🟢 Detected: without_mask: 0.28 at (816, 353, 863, 408)
#
# 0: 384x640 5 with_masks, 3 without_masks, 146.6ms
# Speed: 11.8ms preprocess, 146.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.82 at (1086, 385, 1123, 431)
# 🟢 Detected: without_mask: 0.82 at (467, 397, 508, 440)
# 🟢 Detected: with_mask: 0.80 at (1465, 427, 1528, 487)
# 🟢 Detected: with_mask: 0.75 at (1882, 381, 1919, 429)
# 🟢 Detected: with_mask: 0.67 at (807, 353, 857, 407)
# 🟢 Detected: without_mask: 0.56 at (357, 386, 386, 426)
# 🟢 Detected: with_mask: 0.43 at (661, 382, 701, 433)
# 🟢 Detected: without_mask: 0.39 at (1236, 379, 1275, 423)
#
# 0: 384x640 5 with_masks, 4 without_masks, 149.0ms
# Speed: 10.3ms preprocess, 149.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.88 at (465, 397, 507, 440)
# 🟢 Detected: with_mask: 0.84 at (1082, 383, 1123, 431)
# 🟢 Detected: with_mask: 0.80 at (1468, 430, 1528, 489)
# 🟢 Detected: with_mask: 0.67 at (801, 367, 853, 424)
# 🟢 Detected: without_mask: 0.57 at (349, 381, 384, 426)
# 🟢 Detected: without_mask: 0.48 at (1233, 380, 1269, 423)
# 🟢 Detected: with_mask: 0.37 at (1886, 379, 1919, 430)
# 🟢 Detected: without_mask: 0.29 at (1439, 364, 1479, 410)
# 🟢 Detected: with_mask: 0.26 at (603, 419, 632, 452)
#
# 0: 384x640 3 with_masks, 4 without_masks, 179.7ms
# Speed: 11.1ms preprocess, 179.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.88 at (464, 397, 508, 441)
# 🟢 Detected: with_mask: 0.83 at (1082, 381, 1120, 430)
# 🟢 Detected: with_mask: 0.79 at (1468, 431, 1527, 490)
# 🟢 Detected: without_mask: 0.58 at (350, 381, 382, 424)
# 🟢 Detected: without_mask: 0.43 at (1437, 365, 1478, 410)
# 🟢 Detected: without_mask: 0.39 at (1232, 380, 1268, 422)
# 🟢 Detected: with_mask: 0.33 at (799, 367, 846, 418)
#
# 0: 384x640 5 with_masks, 2 without_masks, 159.8ms
# Speed: 4.4ms preprocess, 159.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: with_mask: 0.83 at (1082, 379, 1118, 429)
# 🟢 Detected: without_mask: 0.79 at (461, 399, 506, 445)
# 🟢 Detected: with_mask: 0.76 at (1470, 433, 1526, 489)
# 🟢 Detected: without_mask: 0.52 at (350, 383, 380, 424)
# 🟢 Detected: with_mask: 0.51 at (792, 365, 841, 416)
# 🟢 Detected: with_mask: 0.31 at (558, 438, 583, 469)
# 🟢 Detected: with_mask: 0.27 at (598, 425, 628, 456)
#
# 0: 384x640 4 with_masks, 3 without_masks, 152.9ms
# Speed: 14.8ms preprocess, 152.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.88 at (458, 396, 505, 446)
# 🟢 Detected: with_mask: 0.81 at (1079, 375, 1116, 427)
# 🟢 Detected: with_mask: 0.76 at (1471, 432, 1526, 488)
# 🟢 Detected: without_mask: 0.51 at (347, 379, 380, 422)
# 🟢 Detected: with_mask: 0.46 at (786, 365, 836, 414)
# 🟢 Detected: with_mask: 0.36 at (1797, 393, 1827, 428)
# 🟢 Detected: without_mask: 0.27 at (344, 375, 376, 418)
#
# 0: 384x640 3 with_masks, 5 without_masks, 151.0ms
# Speed: 18.2ms preprocess, 151.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.92 at (456, 393, 502, 445)
# 🟢 Detected: with_mask: 0.81 at (1079, 374, 1113, 422)
# 🟢 Detected: with_mask: 0.73 at (1469, 430, 1526, 488)
# 🟢 Detected: without_mask: 0.54 at (346, 380, 379, 423)
# 🟢 Detected: without_mask: 0.37 at (342, 377, 374, 419)
# 🟢 Detected: with_mask: 0.34 at (781, 373, 831, 427)
# 🟢 Detected: without_mask: 0.31 at (1437, 359, 1479, 405)
# 🟢 Detected: without_mask: 0.29 at (666, 385, 692, 416)
#
# 0: 384x640 3 with_masks, 4 without_masks, 159.4ms
# Speed: 7.7ms preprocess, 159.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🟢 Detected: without_mask: 0.92 at (453, 390, 498, 441)
# 🟢 Detected: with_mask: 0.84 at (1076, 373, 1113, 424)
# 🟢 Detected: with_mask: 0.64 at (1469, 426, 1525, 486)
# 🟢 Detected: without_mask: 0.60 at (340, 381, 373, 423)
# 🟢 Detected: without_mask: 0.35 at (777, 368, 825, 415)
# 🟢 Detected: without_mask: 0.31 at (1438, 359, 1478, 401)
# 🟢 Detected: with_mask: 0.25 at (1791, 393, 1826, 432)
# Exiting live-cam...
# Recorded video saved as: recordings/recorded_20250624_144614.avi
