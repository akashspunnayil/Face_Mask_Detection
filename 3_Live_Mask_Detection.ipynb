# %% [markdown]
# # Live Face-Mask Detection - Using YOLO pretrained model
# # conda activate yolo

# %%
import cv2
from ultralytics import YOLO
import pygame
import time

# Load custom face mask detection YOLO model
# model = YOLO("/media/akashs/FA22E72622E6E69B/DATA1_disk/MyGithub/Mask_Detection/archive/runs/detect/train2/weights/best.pt")  # Change to your model path
model = YOLO("./best.pt")  # Change to your model path
names = model.names  # Should include 'mask' and 'no_mask'
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
names
# Out:
# {0: 'with_mask', 1: 'without_mask', 2: 'mask_weared_incorrect'}

# %% [markdown]
# ### Detection

# %%
# Access default live-cam (0)
cap = cv2.VideoCapture(0)
# cap = cv2.VideoCapture("mask_video2.mp4")

fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_video_filename = f"recordings/recorded_{time.strftime('%Y%m%d_%H%M%S')}.avi"
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video_filename, fourcc, 20.0, (frame_width, frame_height))


img_counter = 0
print("Live cam started. Press 's' to save image, 'q' to quit.")

# Optional sound setup
pygame.mixer.init()
alert_sound = pygame.mixer.Sound("chime_alert.mp3")

alert_triggered = False

while True:
    ret, frame = cap.read()
    if not ret:
        print("Live cam frame not received")
        break

    # -----------------------------
    # Draw Line, Rectangle, Circle, Text
    # -----------------------------
    height, width = frame.shape[:2]

    results = model(frame)

    # 🔹 Extract results
    boxes = results[0].boxes
    names = model.names  # COCO class names

    # Uses OpenCV's haarcascade
    # https://github.com/opencv/opencv/tree/master/data/haarcascades
    
    detected_classes = [int(box.cls[0].item()) for box in boxes]
    labels = [model.names[cls_id] for cls_id in detected_classes]

    # Draw detection boxes and play alert for "without_mask"
    for box, label in zip(boxes, labels):
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = box.conf[0].item()
        label_text = f"{label}: {conf:.2f}"

        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        cv2.putText(frame, label_text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (255, 0, 0), 2)
        print(f"🟢 Detected: {label_text} at ({x1}, {y1}, {x2}, {y2})")

        # Play sound for each "without_mask" detected
        if "without_mask" in label.lower():
            alert_sound.play()

        
    # -----------------------------
    # Save frame to video file
    # -----------------------------
    out.write(frame)

    # -----------------------------
    # Show live-cam feed
    # -----------------------------
    cv2.imshow('Live-cam Feed with Drawing', frame)

    # -----------------------------
    # Keypress handling
    # -----------------------------
    key = cv2.waitKey(1)
    if key & 0xFF == ord('q'):
        print("Exiting live-cam...")
        break
    elif key & 0xFF == ord('s'):
        # Save snapshot image
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        img_filename = f"snapshot_{timestamp}.jpg"
        cv2.imwrite(img_filename, frame)
        print(f"Snapshot saved: {img_filename}")
        img_counter += 1

# -----------------------------
# Release resources
# -----------------------------
cap.release()
out.release()
cv2.destroyAllWindows()
print(f"Recorded video saved as: {output_video_filename}")
# Out:
# Live cam started. Press 's' to save image, 'q' to quit.
#
# 0: 480x640 (no detections), 50.2ms
# Speed: 4.4ms preprocess, 50.2ms inference, 38.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 with_mask, 8.5ms
# Speed: 4.6ms preprocess, 8.5ms inference, 185.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.32 at (70, 215, 225, 385)
#
# 0: 480x640 1 with_mask, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.65 at (116, 247, 224, 383)
#
# 0: 480x640 1 with_mask, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.45 at (94, 241, 225, 383)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 with_mask, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 22.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.63 at (114, 240, 229, 371)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 3.7ms preprocess, 8.3ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 3.6ms preprocess, 8.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.6ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.36 at (161, 232, 251, 362)
#
# 0: 480x640 1 without_mask, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.26 at (162, 231, 260, 362)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.56 at (163, 237, 251, 361)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.54 at (166, 231, 247, 360)
#
# 0: 480x640 1 without_mask, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.67 at (172, 227, 253, 350)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.41 at (173, 221, 253, 356)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.40 at (172, 220, 256, 355)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.9ms preprocess, 5.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.36 at (177, 211, 269, 323)
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 14.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.76 at (126, 203, 271, 343)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 3.7ms preprocess, 9.1ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.75 at (128, 181, 275, 360)
#
# 0: 480x640 1 without_mask, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.71 at (130, 194, 278, 359)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.59 at (130, 189, 281, 357)
# 🟢 Detected: with_mask: 0.39 at (131, 186, 280, 359)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 35.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.76 at (134, 190, 282, 347)
# 🟢 Detected: with_mask: 0.65 at (135, 192, 282, 345)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 26.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.79 at (141, 186, 282, 349)
# 🟢 Detected: with_mask: 0.64 at (139, 186, 282, 350)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (139, 182, 284, 346)
# 🟢 Detected: with_mask: 0.54 at (136, 182, 285, 354)
#
# 0: 480x640 1 with_mask, 1 without_mask, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.65 at (140, 180, 285, 352)
# 🟢 Detected: without_mask: 0.62 at (141, 181, 284, 347)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 22.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (142, 182, 285, 340)
# 🟢 Detected: with_mask: 0.43 at (142, 181, 285, 342)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 23.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.85 at (146, 182, 288, 344)
#
# 0: 480x640 1 without_mask, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (148, 182, 293, 339)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 23.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (155, 179, 298, 345)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.75 at (156, 179, 302, 338)
# 🟢 Detected: with_mask: 0.66 at (157, 176, 302, 341)
#
# 0: 480x640 1 without_mask, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (163, 178, 307, 344)
#
# 0: 480x640 1 without_mask, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (173, 177, 313, 343)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (173, 177, 317, 340)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 22.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (174, 178, 318, 345)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (180, 178, 324, 340)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (184, 180, 325, 333)
#
# 0: 480x640 1 without_mask, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (195, 178, 330, 340)
#
# 0: 480x640 1 without_mask, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (196, 178, 335, 342)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (203, 181, 342, 335)
# 🟢 Detected: with_mask: 0.50 at (204, 182, 340, 340)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (211, 180, 345, 326)
#
# 0: 480x640 1 without_mask, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.96 at (212, 178, 347, 328)
#
# 0: 480x640 1 without_mask, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (210, 179, 348, 333)
#
# 0: 480x640 1 without_mask, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (215, 176, 349, 329)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (216, 179, 353, 326)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (217, 178, 352, 335)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (217, 179, 356, 326)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (218, 181, 349, 335)
#
# 0: 480x640 1 without_mask, 7.0ms
# Speed: 1.1ms preprocess, 7.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (217, 182, 355, 333)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 1.3ms preprocess, 8.4ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (217, 182, 356, 332)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (217, 182, 355, 347)
#
# 0: 480x640 1 without_mask, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (216, 186, 355, 338)
#
# 0: 480x640 1 without_mask, 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (216, 182, 355, 334)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (217, 184, 354, 340)
#
# 0: 480x640 1 without_mask, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (218, 185, 355, 335)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (219, 183, 356, 339)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (218, 189, 356, 336)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (217, 189, 358, 340)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (216, 191, 358, 347)
#
# 0: 480x640 1 without_mask, 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (219, 195, 360, 349)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.2ms preprocess, 8.3ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (218, 196, 360, 353)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (219, 198, 361, 358)
#
# 0: 480x640 1 without_mask, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (219, 199, 365, 353)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (217, 203, 361, 352)
#
# 0: 480x640 1 without_mask, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (216, 203, 359, 356)
#
# 0: 480x640 1 without_mask, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (215, 201, 357, 360)
#
# 0: 480x640 1 without_mask, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (213, 204, 364, 364)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.1ms
# Speed: 3.1ms preprocess, 5.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (212, 204, 365, 373)
# 🟢 Detected: with_mask: 0.33 at (212, 200, 362, 368)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (212, 209, 363, 371)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 3.9ms preprocess, 8.1ms inference, 23.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (210, 209, 362, 384)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (208, 211, 359, 378)
#
# 0: 480x640 1 without_mask, 8.9ms
# Speed: 3.6ms preprocess, 8.9ms inference, 23.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (208, 211, 359, 387)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 4.2ms preprocess, 8.6ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (213, 213, 360, 372)
# 🟢 Detected: with_mask: 0.48 at (208, 214, 358, 372)
#
# 0: 480x640 1 without_mask, 9.3ms
# Speed: 1.1ms preprocess, 9.3ms inference, 17.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (207, 214, 358, 373)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.9ms
# Speed: 3.7ms preprocess, 8.9ms inference, 22.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (205, 215, 358, 371)
# 🟢 Detected: with_mask: 0.42 at (204, 213, 356, 372)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.8ms
# Speed: 3.3ms preprocess, 8.8ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (210, 214, 358, 379)
# 🟢 Detected: with_mask: 0.49 at (203, 214, 355, 378)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (205, 214, 357, 383)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (205, 214, 357, 370)
# 🟢 Detected: with_mask: 0.40 at (205, 213, 354, 373)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 21.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (212, 211, 359, 370)
# 🟢 Detected: with_mask: 0.55 at (205, 209, 356, 371)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (205, 214, 357, 371)
# 🟢 Detected: with_mask: 0.33 at (204, 213, 355, 374)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (212, 212, 359, 375)
# 🟢 Detected: with_mask: 0.41 at (206, 212, 357, 377)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (205, 211, 358, 371)
# 🟢 Detected: with_mask: 0.62 at (204, 209, 357, 377)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.1ms
# Speed: 3.7ms preprocess, 8.1ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (206, 212, 356, 371)
# 🟢 Detected: with_mask: 0.37 at (205, 211, 354, 377)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (213, 213, 357, 368)
# 🟢 Detected: with_mask: 0.55 at (204, 212, 355, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (204, 211, 358, 395)
# 🟢 Detected: with_mask: 0.58 at (204, 210, 356, 395)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 4.1ms preprocess, 8.6ms inference, 22.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (205, 213, 356, 369)
# 🟢 Detected: with_mask: 0.29 at (204, 211, 354, 370)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (205, 211, 357, 369)
# 🟢 Detected: with_mask: 0.41 at (203, 210, 355, 370)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 22.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (205, 209, 358, 379)
# 🟢 Detected: with_mask: 0.55 at (206, 210, 355, 371)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (205, 209, 357, 382)
# 🟢 Detected: with_mask: 0.42 at (204, 210, 354, 372)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.3ms
# Speed: 3.3ms preprocess, 9.3ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (204, 209, 359, 373)
# 🟢 Detected: with_mask: 0.56 at (204, 209, 356, 368)
#
# 0: 480x640 1 without_mask, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 23.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (206, 209, 359, 380)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (207, 212, 360, 379)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.3ms
# Speed: 2.9ms preprocess, 9.3ms inference, 23.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (206, 208, 360, 384)
# 🟢 Detected: with_mask: 0.29 at (209, 210, 358, 385)
#
# 0: 480x640 1 with_mask, 1 without_mask, 6.1ms
# Speed: 2.8ms preprocess, 6.1ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (209, 210, 360, 375)
# 🟢 Detected: with_mask: 0.30 at (210, 210, 359, 367)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.6ms preprocess, 8.3ms inference, 22.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (209, 209, 362, 377)
#
# 0: 480x640 1 with_mask, 1 without_mask, 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (209, 209, 362, 376)
# 🟢 Detected: with_mask: 0.31 at (211, 209, 360, 369)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (212, 208, 363, 380)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (213, 212, 366, 379)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (214, 209, 369, 377)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (217, 210, 371, 379)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 22.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (217, 206, 372, 382)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (221, 207, 373, 386)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 14.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (221, 208, 373, 380)
#
# 0: 480x640 1 without_mask, 7.9ms
# Speed: 3.2ms preprocess, 7.9ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (220, 206, 374, 381)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 3.0ms preprocess, 8.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (220, 204, 373, 371)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 16.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (223, 203, 372, 360)
#
# 0: 480x640 1 without_mask, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (222, 202, 373, 366)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (222, 199, 373, 362)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (220, 201, 372, 358)
#
# 0: 480x640 1 without_mask, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (219, 204, 372, 366)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (219, 201, 373, 352)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (218, 202, 371, 355)
#
# 0: 480x640 1 without_mask, 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (218, 203, 371, 358)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (217, 201, 372, 357)
#
# 0: 480x640 1 without_mask, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (218, 201, 371, 381)
#
# 0: 480x640 1 without_mask, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (218, 203, 371, 355)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (218, 201, 371, 360)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (220, 200, 371, 363)
#
# 0: 480x640 1 without_mask, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (217, 200, 373, 385)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (217, 204, 371, 369)
#
# 0: 480x640 1 without_mask, 9.7ms
# Speed: 1.1ms preprocess, 9.7ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (216, 203, 371, 366)
#
# 0: 480x640 1 without_mask, 7.7ms
# Speed: 4.0ms preprocess, 7.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (214, 204, 368, 364)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (214, 206, 368, 382)
#
# 0: 480x640 1 without_mask, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (215, 205, 363, 363)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (215, 205, 364, 369)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (207, 207, 360, 368)
#
# 0: 480x640 1 with_mask, 1 without_mask, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.85 at (204, 204, 357, 387)
# 🟢 Detected: with_mask: 0.59 at (207, 203, 354, 385)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.2ms
# Speed: 3.2ms preprocess, 8.2ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.77 at (198, 223, 348, 377)
# 🟢 Detected: with_mask: 0.25 at (197, 222, 346, 380)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 3.1ms preprocess, 8.1ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.50 at (194, 233, 336, 378)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.74 at (194, 235, 324, 378)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.85 at (187, 230, 329, 380)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 4.1ms preprocess, 8.1ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.67 at (178, 231, 319, 380)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 3.3ms preprocess, 8.2ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (172, 225, 318, 382)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 2.9ms preprocess, 8.1ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.83 at (174, 233, 314, 386)
#
# 0: 480x640 1 without_mask, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (177, 235, 306, 375)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (161, 231, 307, 374)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (162, 226, 303, 373)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.81 at (160, 214, 306, 368)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 3.5ms preprocess, 8.4ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (154, 206, 304, 374)
#
# 0: 480x640 1 without_mask, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (155, 211, 301, 364)
#
# 0: 480x640 1 without_mask, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (151, 214, 301, 364)
#
# 0: 480x640 1 without_mask, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (153, 212, 299, 370)
#
# 0: 480x640 1 without_mask, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (155, 213, 299, 367)
#
# 0: 480x640 1 without_mask, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (154, 216, 303, 371)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.65 at (154, 215, 304, 373)
#
# 0: 480x640 1 without_mask, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (155, 214, 307, 373)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.85 at (156, 213, 304, 373)
#
# 0: 480x640 1 without_mask, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (154, 213, 299, 373)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 18.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (152, 215, 298, 365)
#
# 0: 480x640 1 without_mask, 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (151, 210, 297, 370)
#
# 0: 480x640 1 without_mask, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (151, 212, 294, 355)
#
# 0: 480x640 1 without_mask, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (149, 208, 295, 360)
#
# 0: 480x640 1 without_mask, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (148, 207, 298, 359)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 3.5ms preprocess, 8.2ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (152, 208, 298, 358)
#
# 0: 480x640 1 without_mask, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (154, 202, 299, 350)
#
# 0: 480x640 1 without_mask, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (155, 203, 299, 354)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (158, 203, 300, 350)
#
# 0: 480x640 1 without_mask, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (160, 202, 302, 346)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (159, 201, 301, 346)
#
# 0: 480x640 1 without_mask, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (160, 201, 302, 346)
#
# 0: 480x640 1 without_mask, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (161, 200, 304, 346)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (160, 199, 305, 346)
#
# 0: 480x640 1 without_mask, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (161, 200, 306, 347)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (162, 200, 306, 348)
#
# 0: 480x640 1 without_mask, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (161, 199, 307, 345)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 3.3ms preprocess, 8.1ms inference, 21.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (162, 201, 306, 345)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 4.3ms preprocess, 8.6ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (161, 201, 307, 346)
#
# 0: 480x640 1 without_mask, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (160, 200, 307, 342)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 3.2ms preprocess, 8.5ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (161, 203, 305, 355)
#
# 0: 480x640 1 with_mask, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 17.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.81 at (161, 207, 302, 355)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.80 at (160, 221, 298, 357)
# 🟢 Detected: with_mask: 0.51 at (159, 218, 299, 356)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 35.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.79 at (159, 226, 298, 364)
# 🟢 Detected: with_mask: 0.74 at (159, 226, 297, 362)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.78 at (160, 229, 299, 363)
# 🟢 Detected: with_mask: 0.71 at (159, 228, 299, 363)
#
# 0: 480x640 1 without_mask, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (159, 228, 297, 362)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.79 at (159, 225, 293, 365)
#
# 0: 480x640 1 without_mask, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 17.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (157, 227, 294, 364)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.83 at (158, 228, 291, 362)
# 🟢 Detected: with_mask: 0.31 at (157, 228, 292, 362)
#
# 0: 480x640 1 with_mask, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.77 at (156, 227, 293, 363)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 22.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (155, 226, 293, 365)
# 🟢 Detected: with_mask: 0.48 at (155, 227, 293, 364)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.59 at (157, 226, 292, 364)
# 🟢 Detected: with_mask: 0.50 at (156, 226, 292, 363)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 35.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.55 at (153, 225, 292, 366)
# 🟢 Detected: with_mask: 0.41 at (154, 226, 292, 366)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.0ms
# Speed: 2.1ms preprocess, 5.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.76 at (155, 226, 287, 364)
# 🟢 Detected: with_mask: 0.44 at (155, 219, 290, 361)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.1ms
# Speed: 2.9ms preprocess, 8.1ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (153, 223, 291, 366)
# 🟢 Detected: with_mask: 0.34 at (152, 221, 292, 364)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (152, 221, 286, 361)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.76 at (149, 213, 291, 357)
# 🟢 Detected: without_mask: 0.66 at (151, 216, 290, 358)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 35.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (152, 207, 295, 353)
# 🟢 Detected: with_mask: 0.80 at (151, 208, 293, 354)
#
# 0: 480x640 1 without_mask, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (154, 205, 296, 351)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (154, 204, 298, 352)
#
# 0: 480x640 1 without_mask, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (155, 204, 298, 351)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (157, 205, 299, 345)
#
# 0: 480x640 3 with_masks, 8.5ms
# Speed: 3.2ms preprocess, 8.5ms inference, 15.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.47 at (224, 206, 295, 273)
# 🟢 Detected: with_mask: 0.39 at (98, 200, 314, 479)
# 🟢 Detected: with_mask: 0.35 at (159, 206, 296, 300)
#
# 0: 480x640 1 with_mask, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (147, 201, 312, 380)
#
# 0: 480x640 1 with_mask, 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.87 at (145, 205, 314, 358)
#
# 0: 480x640 4 with_masks, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (156, 201, 315, 350)
# 🟢 Detected: with_mask: 0.47 at (205, 203, 316, 350)
# 🟢 Detected: with_mask: 0.28 at (104, 276, 160, 362)
# 🟢 Detected: with_mask: 0.27 at (104, 276, 159, 362)
#
# 0: 480x640 1 with_mask, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (156, 198, 317, 351)
#
# 0: 480x640 2 with_masks, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (160, 198, 318, 351)
# 🟢 Detected: with_mask: 0.40 at (95, 275, 166, 361)
#
# 0: 480x640 2 with_masks, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.92 at (160, 196, 320, 352)
# 🟢 Detected: with_mask: 0.31 at (96, 271, 168, 361)
#
# 0: 480x640 1 with_mask, 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (160, 202, 318, 354)
#
# 0: 480x640 1 with_mask, 8.3ms
# Speed: 3.9ms preprocess, 8.3ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (160, 204, 319, 359)
#
# 0: 480x640 1 with_mask, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (162, 208, 319, 362)
#
# 0: 480x640 1 with_mask, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 16.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (163, 214, 318, 366)
#
# 0: 480x640 1 with_mask, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (164, 218, 318, 370)
#
# 0: 480x640 1 with_mask, 8.7ms
# Speed: 3.7ms preprocess, 8.7ms inference, 16.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (166, 222, 319, 372)
#
# 0: 480x640 2 with_masks, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.92 at (166, 224, 320, 376)
# 🟢 Detected: with_mask: 0.29 at (333, 214, 363, 247)
#
# 0: 480x640 1 with_mask, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (167, 231, 321, 380)
#
# 0: 480x640 1 with_mask, 8.3ms
# Speed: 3.2ms preprocess, 8.3ms inference, 20.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (165, 236, 321, 384)
#
# 0: 480x640 1 with_mask, 8.4ms
# Speed: 3.4ms preprocess, 8.4ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.86 at (166, 239, 319, 388)
#
# 0: 480x640 1 with_mask, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.87 at (163, 239, 318, 390)
#
# 0: 480x640 1 with_mask, 8.7ms
# Speed: 2.9ms preprocess, 8.7ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.88 at (162, 240, 318, 392)
#
# 0: 480x640 1 with_mask, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (160, 241, 317, 392)
#
# 0: 480x640 1 with_mask, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (160, 240, 321, 391)
#
# 0: 480x640 1 with_mask, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (160, 235, 319, 392)
#
# 0: 480x640 1 with_mask, 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (160, 231, 319, 390)
#
# 0: 480x640 1 with_mask, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 20.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (160, 227, 318, 388)
#
# 0: 480x640 2 with_masks, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 36.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (159, 213, 318, 380)
# 🟢 Detected: with_mask: 0.48 at (103, 285, 167, 363)
#
# 0: 480x640 1 with_mask, 8.6ms
# Speed: 3.3ms preprocess, 8.6ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (159, 210, 317, 376)
#
# 0: 480x640 1 with_mask, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.89 at (157, 199, 316, 368)
#
# 0: 480x640 1 with_mask, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (155, 192, 316, 366)
#
# 0: 480x640 1 with_mask, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.91 at (157, 186, 317, 361)
#
# 0: 480x640 2 with_masks, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.90 at (159, 184, 316, 360)
# 🟢 Detected: with_mask: 0.33 at (96, 314, 148, 367)
#
# ...
# 🟢 Detected: without_mask: 0.90 at (129, 206, 289, 372)
# 🟢 Detected: with_mask: 0.32 at (127, 204, 287, 370)
#
# 0: 480x640 1 without_mask, 4.7ms
# Speed: 1.9ms preprocess, 4.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (129, 204, 291, 373)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 22.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (127, 205, 291, 375)
# 🟢 Detected: with_mask: 0.47 at (126, 201, 289, 371)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (129, 204, 291, 372)
# 🟢 Detected: with_mask: 0.47 at (127, 201, 289, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 5.3ms
# Speed: 1.7ms preprocess, 5.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.94 at (127, 203, 291, 373)
# 🟢 Detected: with_mask: 0.42 at (126, 199, 289, 370)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.2ms
# Speed: 1.3ms preprocess, 8.2ms inference, 36.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.78 at (131, 203, 291, 373)
# 🟢 Detected: with_mask: 0.52 at (125, 197, 289, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 22.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (127, 204, 290, 368)
# 🟢 Detected: with_mask: 0.45 at (125, 200, 289, 368)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (126, 205, 290, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.95 at (128, 205, 291, 373)
# 🟢 Detected: with_mask: 0.43 at (126, 202, 289, 370)
#
# 0: 480x640 1 with_mask, 1 without_mask, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (127, 205, 291, 369)
# 🟢 Detected: with_mask: 0.35 at (125, 200, 289, 369)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 2.8ms preprocess, 8.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (129, 205, 291, 368)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (127, 207, 291, 370)
# 🟢 Detected: with_mask: 0.41 at (125, 205, 289, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (127, 204, 290, 368)
# 🟢 Detected: with_mask: 0.38 at (126, 202, 288, 368)
#
# 0: 480x640 1 without_mask, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 19.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (128, 205, 290, 371)
#
# 0: 480x640 1 without_mask, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (128, 205, 290, 367)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (129, 204, 291, 370)
# 🟢 Detected: with_mask: 0.53 at (125, 201, 289, 369)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (131, 205, 290, 366)
#
# 0: 480x640 1 with_mask, 1 without_mask, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 21.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (128, 205, 291, 367)
# 🟢 Detected: with_mask: 0.45 at (127, 200, 289, 368)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 22.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (126, 204, 291, 368)
# 🟢 Detected: with_mask: 0.51 at (126, 200, 290, 368)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 36.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.78 at (128, 205, 292, 369)
# 🟢 Detected: with_mask: 0.56 at (126, 199, 290, 367)
#
# 0: 480x640 1 without_mask, 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (129, 200, 292, 366)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 2.9ms preprocess, 8.5ms inference, 22.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.92 at (129, 200, 292, 368)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (129, 201, 292, 367)
#
# 0: 480x640 1 without_mask, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (130, 199, 290, 365)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (130, 202, 291, 364)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.2ms preprocess, 8.7ms inference, 22.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (133, 201, 293, 366)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (133, 203, 293, 364)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 24.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (131, 201, 293, 369)
# 🟢 Detected: with_mask: 0.25 at (131, 198, 292, 368)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 2.6ms preprocess, 8.4ms inference, 17.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (133, 198, 294, 370)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.93 at (133, 201, 294, 367)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 21.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (132, 202, 292, 368)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 19.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (133, 203, 294, 366)
# 🟢 Detected: with_mask: 0.42 at (132, 200, 291, 365)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.88 at (132, 198, 295, 367)
# 🟢 Detected: with_mask: 0.26 at (131, 196, 293, 366)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 2.7ms preprocess, 8.7ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (133, 200, 294, 366)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (134, 203, 293, 368)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (132, 200, 294, 365)
#
# 0: 480x640 1 without_mask, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (131, 204, 293, 364)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (133, 200, 293, 365)
#
# 0: 480x640 1 without_mask, 8.3ms
# Speed: 1.7ms preprocess, 8.3ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (135, 205, 293, 364)
#
# 0: 480x640 1 with_mask, 1 without_mask, 6.8ms
# Speed: 1.2ms preprocess, 6.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (132, 201, 291, 371)
# 🟢 Detected: with_mask: 0.26 at (131, 198, 289, 369)
#
# 0: 480x640 1 without_mask, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 22.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.87 at (129, 202, 290, 362)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.83 at (125, 206, 287, 363)
#
# 0: 480x640 1 without_mask, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (123, 207, 283, 367)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 3.5ms preprocess, 8.7ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.84 at (121, 206, 283, 365)
#
# 0: 480x640 1 without_mask, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (122, 211, 280, 368)
#
# 0: 480x640 1 without_mask, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.91 at (123, 209, 278, 374)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 3.4ms preprocess, 8.8ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.56 at (118, 212, 278, 371)
#
# 0: 480x640 1 without_mask, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (119, 212, 275, 369)
#
# 0: 480x640 1 without_mask, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.68 at (117, 212, 275, 368)
#
# 0: 480x640 1 without_mask, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.89 at (116, 213, 273, 369)
#
# 0: 480x640 1 without_mask, 7.4ms
# Speed: 2.7ms preprocess, 7.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.54 at (117, 214, 277, 368)
#
# 0: 480x640 1 without_mask, 9.1ms
# Speed: 3.2ms preprocess, 9.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (122, 216, 274, 369)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.79 at (119, 214, 271, 369)
# 🟢 Detected: with_mask: 0.33 at (110, 214, 268, 371)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.63 at (115, 217, 266, 370)
# 🟢 Detected: with_mask: 0.37 at (104, 217, 263, 371)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.65 at (102, 217, 262, 371)
# 🟢 Detected: with_mask: 0.40 at (102, 214, 261, 372)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 21.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.80 at (100, 220, 262, 376)
# 🟢 Detected: with_mask: 0.37 at (100, 219, 261, 377)
#
# 0: 480x640 1 with_mask, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 21.3ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.70 at (101, 222, 258, 376)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.57 at (102, 220, 259, 380)
# 🟢 Detected: with_mask: 0.56 at (97, 220, 258, 378)
#
# 0: 480x640 1 without_mask, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.29 at (138, 220, 256, 382)
#
# 0: 480x640 1 with_mask, 1 without_mask, 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.38 at (99, 230, 256, 378)
# 🟢 Detected: without_mask: 0.33 at (127, 225, 258, 380)
#
# 0: 480x640 1 with_mask, 1 without_mask, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.43 at (156, 240, 263, 383)
# 🟢 Detected: with_mask: 0.31 at (111, 240, 263, 383)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.54 at (111, 243, 266, 381)
#
# 0: 480x640 1 with_mask, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.48 at (118, 248, 270, 384)
#
# 0: 480x640 1 with_mask, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.78 at (125, 249, 275, 384)
#
# 0: 480x640 1 with_mask, 8.2ms
# Speed: 3.4ms preprocess, 8.2ms inference, 21.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.63 at (125, 243, 275, 381)
#
# 0: 480x640 1 with_mask, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.80 at (125, 242, 276, 381)
#
# 0: 480x640 1 with_mask, 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.81 at (131, 242, 282, 381)
#
# 0: 480x640 1 with_mask, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.63 at (128, 243, 283, 379)
#
# 0: 480x640 1 with_mask, 8.6ms
# Speed: 3.3ms preprocess, 8.6ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.73 at (132, 242, 287, 381)
#
# 0: 480x640 1 with_mask, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.63 at (135, 241, 287, 378)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 22.0ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.76 at (136, 240, 286, 379)
# 🟢 Detected: with_mask: 0.27 at (133, 241, 286, 379)
#
# 0: 480x640 1 with_mask, 1 without_mask, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: with_mask: 0.72 at (134, 241, 287, 379)
# 🟢 Detected: without_mask: 0.70 at (140, 240, 288, 379)
#
# 0: 480x640 1 with_mask, 1 without_mask, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 16.9ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.54 at (140, 230, 292, 373)
# 🟢 Detected: with_mask: 0.48 at (138, 226, 292, 374)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.72 at (137, 217, 290, 374)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 3.7ms preprocess, 8.8ms inference, 21.2ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.86 at (131, 207, 291, 365)
#
# 0: 480x640 1 without_mask, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 21.6ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected: without_mask: 0.90 at (132, 208, 291, 366)
# Exiting live-cam...
# Recorded video saved as: recordings/recorded_20250910_165618.avi
